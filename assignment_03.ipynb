# %% [markdown]
# # Assignment on Linear Regression
#
# ✅ This assignment is completed by `Mohammad Khorshed Alam`
#
# ---

# %%
# Importing required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Created a dictornary with the given data

data = {
    'Weight' : [2, 4, 5, 3, 6, 5, 7],
    'Price' : [35, 60, 20, 50, 50, 55, 60]
}

# %%
# Created  a DataFrame with the given data

df = pd.DataFrame(data)
df
# Out:
#    Weight  Price
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50
# 5       5     55
# 6       7     60

# %%
# Visualization of the data

plt.scatter(df['Weight'], df['Price'], marker= 'D')
plt.xlabel('Weight')
plt.ylabel('Price')
plt.title('Weight vs Price')
# Out:
# Text(0.5, 1.0, 'Weight vs Price')

# %% [markdown]
# ### Task-1: Computing Slope (m) and Y-intercept (c), and prediction for weight 6.50

# %%
# Manually calculating slope (m) and intercept (c) and prediction for weight 6.50

x = df['Weight']
y = df['Price']

mean_x = np.mean(df['Weight'])
mean_y = np.mean(df['Price'])

div_x = x -  mean_x
div_y = y -  mean_y

m = np.sum(div_x * div_y) / np.sum(div_x ** 2)
c = mean_y - m * mean_x

print(f"m = {float(m): .2f}")
print(f"c = {float(c): .2f}")

print(f"Price for 6.50 weight: {float(m * 6.5 + c): .2f}")
# Out:
# m =  2.62
# c =  35.16
# Price for 6.50 weight:  52.20

# %%
# Calculating slope (m) and intercept (c) and prediction for weight 6.50 using library

from sklearn.linear_model import LinearRegression

reg =  LinearRegression()

reg.fit(df[['Weight']], df['Price'])
# Out:
# LinearRegression()

# %%
reg.coef_   # Slope m
# Out:
# array([2.62096774])

# %%
reg.intercept_   # Y-intercept c
# Out:
# np.float64(35.16129032258065)

# %%
reg.predict([[6.5]])   # Price prediction for 6.5 weight
# Out:
# c:\Users\Babu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([52.19758065])

# %%
print(f"Slope (m): {float(reg.coef_): .2f}")
print(f"Y-intercept (c): {float(reg.intercept_): .2f}")

print(f"Price for 6.50 weight: {float(reg.predict([[6.5]])): .2f}")
# Out:
# Slope (m):  2.62
# Y-intercept (c):  35.16
# Price for 6.50 weight:  52.20
# C:\Users\Babu\AppData\Local\Temp\ipykernel_20456\4291590814.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Slope (m): {float(reg.coef_): .2f}")
# c:\Users\Babu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Babu\AppData\Local\Temp\ipykernel_20456\4291590814.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %% [markdown]
# ### Task-2: Computing the residuals for each data point

# %%
# Created a column with the residuals for each point

df['Residual'] = df['Price'] - reg.predict(df[['Weight']])
df
# Out:
#    Weight  Price   Residual
# 0       2     35  -5.403226
# 1       4     60  14.354839
# 2       5     20 -28.266129
# 3       3     50   6.975806
# 4       6     50  -0.887097
# 5       5     55   6.733871
# 6       7     60   6.491935

# %%
# Computing trainning  score

reg.score(df[['Weight']], df['Price'])
# Out:
# 0.09412315095348434

# %%
# Visualization of the data with best fit line

M =  reg.coef_
C = reg.intercept_

equation = f"y = {float(M): .2f}x + {float(C): .2f}"
plt.text(min(df['Weight']), max(df['Price']) - 5, equation)

plt.scatter(df['Weight'], df['Price'], marker= 'D', label = 'Actual Data', zorder = 1)
plt.plot(df['Weight'], reg.predict(df[['Weight']]), c='c', label = 'Best Fit Line', zorder = 2)
plt.scatter(df['Weight'], reg.predict(df[['Weight']]), c='k', marker= '+', label = 'Predicted Price', zorder = 3)
plt.xlabel('Weight')
plt.ylabel('Price')
plt.title('Weight vs Price')
plt.legend()
# Out:
# C:\Users\Babu\AppData\Local\Temp\ipykernel_20456\2890849512.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   equation = f"y = {float(M): .2f}x + {float(C): .2f}"
